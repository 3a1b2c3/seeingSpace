# %%
# TiNeuVox: Time-Aware Neural Voxels https://github.com/hustvl/TiNeuVox

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
# !nvidia-smi
# Out:
# Wed Jun  8 13:28:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#!apt update && apt install build-essential git python3-dev python3-pip libopenexr-dev libxi-dev libglfw3-dev libglew-dev libomp-dev libxinerama-dev libxcursor-dev
# !pip install --upgrade cmake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone --recursive https://github.com/hustvl/TiNeuVox
#%cd /content/TiNeuVox
# !pwd
# Out:
# fatal: destination path 'TiNeuVox' already exists and is not an empty directory.
# /content/dfs

# %%
#For real dynamic scenes: The dataset provided in HyperNeRF is used. 246 MB
# You can download scenes from Hypernerf Dataset and organize them as Nerfies.
# !wget /content/sample_data -P /content/sample_data https://www.dropbox.com/s/0bf6fl0ye2vz3vr/data.zip
# !unzip /content/sample_data/data.zip -d /content/TiNeuVox
# !mv /content/TiNeuVox/data /content/TiNeuVox/data_dnerf
# Out:
# /content/sample_data: Scheme missing.
# --2022-06-08 13:28:53--  https://www.dropbox.com/s/0bf6fl0ye2vz3vr/data.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/0bf6fl0ye2vz3vr/data.zip [following]
# --2022-06-08 13:28:53--  https://www.dropbox.com/s/raw/0bf6fl0ye2vz3vr/data.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc02295961fd1b0e39553dbf10ce.dl.dropboxusercontent.com/cd/0/inline/Bm26HFMgmSJUmbNa66cGLdmHbQHgAXzLXLECDQtwhwQ1ivSToZ1TKhhKoXEmCAGLTSxirZqsrBIJRI_U8FEkb7AIpdUbarfJCVvbj_uFLr_ZMfB_oy0CJ1qmS1_QGwvOab1cfnRUqL14VPTl3Op08yGl3sYyLUTf8NMnn4hn22NnbA/file# [following]
# ...

# %%
# 415 MB The dataset provided in HyperNeRF is used. You can download scenes from Hypernerf Dataset and organize them as Nerfies.
#!wget /content/sample_data https://github.com/google/hypernerf/releases/download/v0.1/interp_chickchicken.zip
# !unzip /content/sample_data/interp_chickchicken.zip -d /content/TiNeuVox
# !mv /content/TiNeuVox/chickchicken /content/TiNeuVox/vrig-chicken
# Out:
# Archive:  /content/sample_data/interp_chickchicken.zip
#    creating: /content/TiNeuVox/chickchicken/camera/
#   inflating: /content/TiNeuVox/chickchicken/camera/000211.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000427.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000052.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000434.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000109.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000236.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000079.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000392.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000029.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000088.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000277.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000030.json
#   inflating: /content/TiNeuVox/chickchicken/camera/000187.json
# ...

# %%
#%env TCNN_CUDA_ARCHITECTURES=75
# !cmake . -B build -DNGP_BUILD_WITH_GUI=OFF
# Out:
# CMake Error: The source directory "/content/dfs" does not appear to contain CMakeLists.txt.
# Specify --help for usage, or press the help button on the CMake GUI.

# %%
#!cmake --build build --config RelWithDebInfo -j `nproc`

# %%
# !pip3 install -r /content/TiNeuVox/requirements.txt
# !pip3 install Ninja
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/TiNeuVox/requirements.txt'
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
scene0="/content/drive/MyDrive/ColabNERF/macro"
#/content/TiNeuVox/run.py
#!python /content/TiNeuVox/run.py -h
#!python /content/TiNeuVox/run.py --config configs/nerf-*/standup.py 
#!python /content/TiNeuVox/run.py --config /content/TiNeuVox/configs/nerf-base/standup.py --render_test --render_only --eval_psnr
# !python /content/TiNeuVox/run.py --config /content/sample_data/vrig_chicken/configs/vrig_dataset/chicken.py
# Out:
# python3: can't open file '/content/TiNeuVox/run.py': [Errno 2] No such file or directory

# %%
#Evaluation
# !pwd
# !python /content/TiNeuVox/run.py --config /content/TiNeuVox/configs/nerf-base/standup.py# --render_test --render_only --eval_psnr --eval_lpips_vgg --eval_ssim 
#No such file or directory: './logs/nerf_synthetic/base/dnerf_standup-400/fine_last.tar
# Out:
# /content/dfs
# python3: can't open file '/content/TiNeuVox/run.py': [Errno 2] No such file or directory

# %%
#Evaluation
# !pwd
# !python /content/TiNeuVox/run.py --config /content/TiNeuVox/configs/vrig_dataset/chicken.py #--render_test --render_only --eval_psnr --eval_lpips_vgg --eval_ssim
# Out:
# /content/dfs
# python3: can't open file '/content/TiNeuVox/run.py': [Errno 2] No such file or directory
