# %%
#if your data is on goolge drive or you want to copy your results there mount it
from google.colab import drive
drive.mount('/content/drive')

# %%
# https://github.com/yashbhalgat/HashNeRF-pytorch
# !nvidia-smi

# %%
# !git clone --recursive https://github.com/yashbhalgat/HashNeRF-pytorch.git
# %cd HashNeRF-pytorch
# Out:
# fatal: destination path 'HashNeRF-pytorch' already exists and is not an empty directory.
# /content/HashNeRF-pytorch

# %%
#https://drive.google.com/drive/folders/1JDdLGDruGNXWnM1eqY1FNL9PlStjaKWi
#!pip3 install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# run colmap if the data doesnt have a transforms.json yet like
# !python run_nerf.py --config configs/chair.txt --finest_res 512 --log2_hashmap_size 19 --lrate 0.01 --lrate_decay 10
# Out:
# Traceback (most recent call last):
#   File "run_nerf.py", line 18, in <module>
#     from run_nerf_helpers import *
#   File "/content/HashNeRF-pytorch/run_nerf_helpers.py", line 7, in <module>
#     from hash_encoding import HashEmbedder, SHEncoder
#   File "/content/HashNeRF-pytorch/hash_encoding.py", line 8, in <module>
#     from utils import get_voxel_vertices
#   File "/content/HashNeRF-pytorch/utils.py", line 6, in <module>
#     from ray_utils import get_rays, get_ray_directions, get_ndc_rays
#   File "/content/HashNeRF-pytorch/ray_utils.py", line 2, in <module>
#     from kornia import create_meshgrid
# ModuleNotFoundError: No module named 'kornia'

# %%
scene="./instant-ngp/data/nerf/fox"
screenshot_dir="/content/drive/MyDrisve/ColabNERF/fox/render"
snap="/content/drive/MyDrive/ColabNERF/fox/snap/fox_abb8.msgpack"
model0="/content/sample_data/render.obj" 
width=540
height=540
# to see commandline help
#!python .s/scripts/run.py -h
#to save a snapshot
# !python /content/instant-ngp/scripts/run.py  --save_mesh {model0} --mode nerf --scene {scene} --height {height} --width {width} --screenshot_dir {screenshot_dir} -save_snapshot {snap}
# to render from a snapshot uncomment
#!python /content/instant-ngp/scripts/run.py  --save_mesh {model0} --mode nerf --scene {scene} --height {height} --width {width} --screenshot_dir {screenshot_dir} --load_snapshot {snap0}
