# %%
#https://github.com/hustvl/TiNeuVox

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# !nvidia-smi

# %%
# !apt update && apt install build-essential git python3-dev python3-pip libopenexr-dev libxi-dev libglfw3-dev libglew-dev libomp-dev libxinerama-dev libxcursor-dev
# !pip install --upgrade cmake

# %%
#The dataset provided in [HyperNeRF](https://github.com/google/hypernerf) is used. You can download scenes from [Hypernerf Dataset](https://github.com/google/hypernerf/releases/tag/v0.1) and organize them as [Nerfies](https://github.com/google/nerfies#datasets).
# !wget -P /content/sample_data https://github.com/google/hypernerf/archive/refs/tags/v0.1.zip
# !unzip /content/sample_data/vrig_chicken

# %%
# !git clone --recursive https://github.com/hustvl/TiNeuVox

# %%
#%env TCNN_CUDA_ARCHITECTURES=75
# !cmake . -B build -DNGP_BUILD_WITH_GUI=OFF

# %%
# !cmake --build build --config RelWithDebInfo -j `nproc`

# %%
# !pip3 install -r /content/TiNeuVox/requirements.txt
# !pip3 install Ninja

# %%
scene0="/content/drive/MyDrive/ColabNERF/macro"
#/content/TiNeuVox/run.py

#!python /content/TiNeuVox/run.py --config configs/nerf-*/standup.py 
# !python /content/TiNeuVox/run.py --config /content/sample_data/configs/vrig_dataset/chicken.py --render_test --render_only --eval_psnr
#!python /content/TiNeuVox/run.py --config /content/sample_data/vrig_chicken/configs/vrig_dataset/chicken.py

# %% [markdown]
# ## Evaluation
# !python run.py --config configs/nerf-small/standup.py --render_test --render_only --eval_psnr --eval_lpips_vgg --eval_ssim

# %% [markdown]
# # New Section
