# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Inspired by and modified from here https://github.com/NVlabs/instant-ngp/discussions/147
# Note: NVIDIA instant Nerf uses a commercial license, please check it https://github.com/NVlabs/instant-ngp

# !nvidia-smi

# %%
# !apt update && apt install build-essential git python3-dev python3-pip libopenexr-dev libxi-dev libglfw3-dev libglew-dev libomp-dev libxinerama-dev libxcursor-dev
# !pip install --upgrade cmake

# %%
# !git clone --recursive https://github.com/nvlabs/instant-ngp
# %cd instant-ngp

# %%
#%env TCNN_CUDA_ARCHITECTURES=75
# !cmake . -B build -DNGP_BUILD_WITH_GUI=OFF

# %%
# !cmake --build build --config RelWithDebInfo -j `nproc`

# %%
# !pip3 install -r requirements.txt

# %%
#!python ./scripts/run.py -h
#!python /content/instant-ngp/scripts/run.py  --mode nerf --scene /content/drive/MyDrive/ColabNERF/table/images --screenshot_frames [1,10,20]  --screenshot_dir /content/drive/MyDrive/ColabNERF/table/snap --save_snapshot /content/drive/MyDrive/ColabNERF/table/snap/s1.msgpack --screenshot_frames [1,10,20]  --screenshot_dir /content/drive/MyDrive/ColabNERF/table/render/a
#!python /content/instant-ngp/scripts/run.py  --save_mesh /content/drive/MyDrive/ColabNERF/table/render/m.obj --mode nerf --scene /content/drive/MyDrive/ColabNERF/table/images --screenshot_frames [1,10,20]  --screenshot_dir /content/drive/MyDrive/ColabNERF/table/snap --load_snapshot /content/drive/MyDrive/ColabNERF/table/snap/s1.msgpack --screenshot_frames [1,10,20]  --screenshot_dir /content/drive/MyDrive/ColabNERF/table/render/a
# !python /content/instant-ngp/scripts/run.py   --screenshot_dir /content/drive/MyDrive/ColabNERF/table/snap --mode nerf --scene /content/drive/MyDrive/ColabNERF/table/images  --load_snapshot /content/drive/MyDrive/ColabNERF/table/snap/s1.msgpack 

#python d:\pworkspace\seeingSpace\nerfs\candidates\selected__\instant-ngp\scripts\run.py --screenshot_spp 0  --scene data/nerf/fox --mode nerf --marching_cubes_res 16  --save_snapshot 1 --n_steps 3 --height 2000 --gui
